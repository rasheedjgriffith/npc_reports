# %%
import requests
from bs4 import BeautifulSoup

# %%
Jiang151 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htm'

# %%
response = requests.get(Jiang151)

# %%
soup = BeautifulSoup (response.content, 'html.parser')

# %%
len (soup.find_all ('table'))
# Out:
# 30

# %%
print(Jiang151)
# Out:
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htm

# %%
print(soup.get_text(Jiang151))
# Out:
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htm
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htm
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htm
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htm
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htm
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htm
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htm Hold High the Great Banner of Deng Xiaoping Theory for an All-round Advancement of the Cause of Building Socialism With Chinese Characteristics’ Into the 21st Century -- Beijing Reviewhttp://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htm
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htm
# <!--
# function showMenu() {
#     document.getElementById('china_menu').style.display = 'block';
# }
#
# function hideMenu() {
# ...

# %%
Jiang152 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_2.htm'

# %%
response = requests.get (Jiang152)

# %%
soup = BeautifulSoup (response.content, 'html.parser')

# %%
len (soup.find_all ('table'))
# Out:
# 30

# %%
print(soup.get_text(Jiang152))
# Out:
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_2.htm
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_2.htm
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_2.htm
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_2.htm
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_2.htm
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_2.htm
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_2.htm Hold High the Great Banner of Deng Xiaoping Theory for an All-round Advancement of the Cause of Building Socialism With Chinese Characteristics’ Into the 21st Century -- Beijing Reviewhttp://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_2.htm
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_2.htm
# <!--
# function showMenu() {
#     document.getElementById('china_menu').style.display = 'block';
# }
#
# function hideMenu() {
# ...

# %%
table_text = soup.find_all ('table')[1]

# %%
print(table_text)
# Out:
# <table border="0" cellpadding="0" cellspacing="0" width="1000">
# <tr>
# <td bgcolor="#F0F0F0" valign="top" width="170"><table border="0" cellpadding="0" cellspacing="0" width="100%"> <tr> <td><a href="http://doc.bjreview.com/e-magazine/en/2013/MLXJ-E/flipviewerxpress.html" target="_blank"><img border="0" src="../../../images/attachement/jpg/site23/20131016/0023aea8ba4913c8397502.jpg" width="170"/></a></td> </tr> </table>
# <table bgcolor="#AACAD9" border="0" cellpadding="0" cellspacing="0" width="170">
# <tr>
# <td align="center" bgcolor="#CFE0E8" class="f16 bian080204" height="30"><a class="f16" href="../../../../print/node_61041.htm" target="_blank">e-magazine</a></td>
# </tr>
# </table>
# <table bgcolor="#CFE0E8" border="0" cellpadding="0" cellspacing="0" width="170">
# <tr>
# ...

# %%
table_text = soup.find_all ('table')[1].get_text()

# %%
print (table_text)
# Out:
#
#
#
# e-magazine
#
#
#
#
#
#   The Hot Zone   China's newly announced air defense identification zone over the East China Sea aims to shore up national security
#
#
#
#
#
#
# Current Issue
#
#
# ·
#                         Table of Contents
#
#                     ·
#                       Editor's Desk
#
# ·
#                         Previous Issues
#
# · Subscribe to Mag
#
#
#
#
#
#
# Subscribe Now >>
#
#
#
#
#
# Expert's View
#
#
#
#
#
# World
#
#
#
#
#
# Nation
#
#
#
#
#
# Business
#
#
#
#
#
# Finance
#
#
#
#
#
# Market Watch
#
#
#
#
#
# Legal-Ease
#
#
#
#
#
# North American Report
#
#
#
#
#
# Forum
#
#
#
#
#
# Government Documents
#
#
#
#
#
# Expat's Eye
#
#
#
#
#
# Health
#
#
#
#
#
# Science/Technology
#
#
#
#
#
# Lifestyle
#
#
#
#
#
# Books
#
#
#
#
#
# Movies
#
#
#
#
#
# Backgrounders
#
#
#
#
#
# Special
#
#
#
#
#
# Photo Gallery
#
#
#
#
#
# Blogs
#
#
#
#
#
#
#
# Reader's Service
#
#
# Learning with
#               'Beijing Review'
#
#
# E-mail us
#
#
# RSS Feeds
#
#
# ...

# %%
# %history
# Out:
# import requests
# from bs4 import BeautifulSoup
# Jiang151 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htm'
# response = requests.get(Jiang151)
# soup = BeautifulSoup (response.content, 'html.parser')
# print(soup.get_text())
# print(soup.get_text(Jiang151))
# len(soup.find_all('table'))
# len (soup.find_all('table'))
# len (soup.find_all ('table'))
# print(Jiang151)
# print(soup.get_text(Jiang151))
# Jiang152 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_2.htm'
# response = requests.get(Jiang152)
# soup = BeautifulSoup (response.content, 'html.parser')
# len (soup.find_all ('table'))
# print(soup.get_text(Jiang152))
# table_text = soup.find_all ('table')[1]
# print(table_text)
# soup.find_all ('table')[1].get_text()
# print (table_text)
# table_text = soup.find_all ('table')[1].get_text()
# print (table_text)
# table_text = soup.find_all ('table')[1].get_text()
# print (table_text)
# print (table_text)
# print (table_text)
# %history

# %%
def get_html_text ():
    Jiang151 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htm'
    response = requests.get(Jiang151)
    soup = BeautifulSoup (response.content, 'html.parser')
    table_text = soup.find_all ('table')[1].get_text()
    return table_text

# %%
print (get_html_text())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-24f4c136ad83> in <module>
# ----> 1 print (get_html_text())
#
# <ipython-input-33-de9020c66833> in get_html_text()
#       1 def get_html_text ():
#       2     Jiang151 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htm'
# ----> 3     response = requests.get(Jiang151)
#       4     soup = BeautifulSoup (response.content, 'html.parser')
#       5     table_text = soup.find_all ('table')[1].get_text()
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
# ...

# %%
print ("hello")
# Out:
# hello

# %%
print ("slow")
# Out:
# slow

# %%
Jiang151 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htm'
response = requests.get(Jiang151)
soup = BeautifulSoup (response.content, 'html.parser')
table_text = soup.find_all ('table')[1].get_text()

# %%
print (table_text)
# Out:
#
#
#
# e-magazine
#
#
#
#
#
#   The Hot Zone   China's newly announced air defense identification zone over the East China Sea aims to shore up national security
#
#
#
#
#
#
# Current Issue
#
#
# ·
#                         Table of Contents
#
#                     ·
#                       Editor's Desk
#
# ·
#                         Previous Issues
#
# · Subscribe to Mag
#
#
#
#
#
#
# Subscribe Now >>
#
#
#
#
#
# Expert's View
#
#
#
#
#
# World
#
#
#
#
#
# Nation
#
#
#
#
#
# Business
#
#
#
#
#
# Finance
#
#
#
#
#
# Market Watch
#
#
#
#
#
# Legal-Ease
#
#
#
#
#
# North American Report
#
#
#
#
#
# Forum
#
#
#
#
#
# Government Documents
#
#
#
#
#
# Expat's Eye
#
#
#
#
#
# Health
#
#
#
#
#
# Science/Technology
#
#
#
#
#
# Lifestyle
#
#
#
#
#
# Books
#
#
#
#
#
# Movies
#
#
#
#
#
# Backgrounders
#
#
#
#
#
# Special
#
#
#
#
#
# Photo Gallery
#
#
#
#
#
# Blogs
#
#
#
#
#
#
#
# Reader's Service
#
#
# Learning with
#               'Beijing Review'
#
#
# E-mail us
#
#
# RSS Feeds
#
#
# ...

# %%
def get_html_text ():
    Jiang151 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htm'
    response = requests.get(Jiang151)
    soup = BeautifulSoup (response.content, 'html.parser')
    table_text = soup.find_all ('table')[1].get_text()
    return table_text

# %%
print (get_html_text())
# Out:
#
#
#
# e-magazine
#
#
#
#
#
#   The Hot Zone   China's newly announced air defense identification zone over the East China Sea aims to shore up national security
#
#
#
#
#
#
# Current Issue
#
#
# ·
#                         Table of Contents
#
#                     ·
#                       Editor's Desk
#
# ·
#                         Previous Issues
#
# · Subscribe to Mag
#
#
#
#
#
#
# Subscribe Now >>
#
#
#
#
#
# Expert's View
#
#
#
#
#
# World
#
#
#
#
#
# Nation
#
#
#
#
#
# Business
#
#
#
#
#
# Finance
#
#
#
#
#
# Market Watch
#
#
#
#
#
# Legal-Ease
#
#
#
#
#
# North American Report
#
#
#
#
#
# Forum
#
#
#
#
#
# Government Documents
#
#
#
#
#
# Expat's Eye
#
#
#
#
#
# Health
#
#
#
#
#
# Science/Technology
#
#
#
#
#
# Lifestyle
#
#
#
#
#
# Books
#
#
#
#
#
# Movies
#
#
#
#
#
# Backgrounders
#
#
#
#
#
# Special
#
#
#
#
#
# Photo Gallery
#
#
#
#
#
# Blogs
#
#
#
#
#
#
#
# Reader's Service
#
#
# Learning with
#               'Beijing Review'
#
#
# E-mail us
#
#
# RSS Feeds
#
#
# ...

# %%
def get_html_text_two (url='http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htm'):
    response = requests.get(url)
    soup = BeautifulSoup (response.content, 'html.parser')
    table_text = soup.find_all ('table')[1].get_text()
    return table_text

# %%
Jiang_npc151 = get_html_text_two()

# %%
print (Jiang152)
# Out:
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_2.htm

# %%
Jiang_npc152 = get_html_text_two(url=Jiang152)

# %%
Jiang153 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_3.htm'

# %%
Jiang_npc153 = get_html_text_two(Jiang153)

# %%
Jiang154 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_4.htm'

# %%
Jiang_npc154 = get_html_text_two(Jiang154)

# %%
Jiang155 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_5.htm'

# %%
Jiang_npc155 = get_html_text_two(Jiang155)

# %%
Jiang156 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_6.htm'

# %%
Jiang_npc156 = get_html_text_two(Jiang156)

# %%
Jiang157 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_7.htm'

# %%
Jiang_npc157 = get_html_text_two(Jiang157)

# %%
Jiang158 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_8.htm'

# %%
Jiang_npc158 = get_html_text_two(Jiang158)

# %%
Jiang_next = ['http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_9.htm', 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_10.htm']

# %%
Jiang159 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_9.htm'

# %%
Jiang_npc159 = get_html_text_two(Jiang159)

# %%
Jiang1510 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_10.htm'

# %%
Jiang_npc1510 = get_html_text_two(Jiang1510)

# %%
Jiang1511 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_11.htm'

# %%
Jiang_npc1511 = get_html_text_two(Jiang1511)

# %%
Jiang1512 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_12.htm'

# %%
Jiang_npc1512 = get_html_text_two(Jiang1512)

# %%
Jiang1513 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_13.htm'

# %%
Jiang_npc1513 = get_html_text_two(Jiang1513)

# %%
Jiang1514 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_14.htm'

# %%
Jiang_npc1514 = get_html_text_two(Jiang1514)

# %%
Jiang1515 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_15.htm'

# %%
Jiang_npc1515 = get_html_text_two(Jiang1515)

# %%
Jiang1516 = 'http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_16.htm'

# %%
Jiang_npc1516 = get_html_text_two(Jiang1516)

# %%
print (Jiang_npc1516)
# Out:
#
#
#
# e-magazine
#
#
#
#
#
#   The Hot Zone   China's newly announced air defense identification zone over the East China Sea aims to shore up national security
#
#
#
#
#
#
# Current Issue
#
#
# ·
#                         Table of Contents
#
#                     ·
#                       Editor's Desk
#
# ·
#                         Previous Issues
#
# · Subscribe to Mag
#
#
#
#
#
#
# Subscribe Now >>
#
#
#
#
#
# Expert's View
#
#
#
#
#
# World
#
#
#
#
#
# Nation
#
#
#
#
#
# Business
#
#
#
#
#
# Finance
#
#
#
#
#
# Market Watch
#
#
#
#
#
# Legal-Ease
#
#
#
#
#
# North American Report
#
#
#
#
#
# Forum
#
#
#
#
#
# Government Documents
#
#
#
#
#
# Expat's Eye
#
#
#
#
#
# Health
#
#
#
#
#
# Science/Technology
#
#
#
#
#
# Lifestyle
#
#
#
#
#
# Books
#
#
#
#
#
# Movies
#
#
#
#
#
# Backgrounders
#
#
#
#
#
# Special
#
#
#
#
#
# Photo Gallery
#
#
#
#
#
# Blogs
#
#
#
#
#
#
#
# Reader's Service
#
#
# Learning with
#               'Beijing Review'
#
#
# E-mail us
#
#
# RSS Feeds
#
#
# ...

# %%
Jiang = Jiang_npc1516 + '' + Jiang_npc1515

# %%
print (Jiang)
# Out:
#
#
#
# e-magazine
#
#
#
#
#
#   The Hot Zone   China's newly announced air defense identification zone over the East China Sea aims to shore up national security
#
#
#
#
#
#
# Current Issue
#
#
# ·
#                         Table of Contents
#
#                     ·
#                       Editor's Desk
#
# ·
#                         Previous Issues
#
# · Subscribe to Mag
#
#
#
#
#
#
# Subscribe Now >>
#
#
#
#
#
# Expert's View
#
#
#
#
#
# World
#
#
#
#
#
# Nation
#
#
#
#
#
# Business
#
#
#
#
#
# Finance
#
#
#
#
#
# Market Watch
#
#
#
#
#
# Legal-Ease
#
#
#
#
#
# North American Report
#
#
#
#
#
# Forum
#
#
#
#
#
# Government Documents
#
#
#
#
#
# Expat's Eye
#
#
#
#
#
# Health
#
#
#
#
#
# Science/Technology
#
#
#
#
#
# Lifestyle
#
#
#
#
#
# Books
#
#
#
#
#
# Movies
#
#
#
#
#
# Backgrounders
#
#
#
#
#
# Special
#
#
#
#
#
# Photo Gallery
#
#
#
#
#
# Blogs
#
#
#
#
#
#
#
# Reader's Service
#
#
# Learning with
#               'Beijing Review'
#
#
# E-mail us
#
#
# RSS Feeds
#
#
# ...

# %%
Jiang_npc15 = Jiang_npc151 + '' + Jiang_npc152 + ''  +Jiang_npc153 + '' + Jiang_npc154 + '' + Jiang_npc155 + '' + Jiang_npc156 + '' + Jiang_npc157 + '' + Jiang_npc158 +''+ Jiang_npc159 + '' + Jiang_npc1510 + '' + Jiang_npc1511 + '' + Jiang_npc1512 + '' + Jiang_npc1513 + ''+ Jiang_npc1514 + ''+ Jiang_npc1515 + ''+ Jiang_npc1516

# %%
print (Jiang_npc15)
# Out:
# http://www.bjreview.com.cn/document/txt/2011-03/25/content_363499.htmhttp://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_2.htmhttp://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_3.htmhttp://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_4.htmhttp://www.bjreview.com.cn/document/txt/2011-03/25/content_363499_5.htm

# %%
Jiang_npc15 = Jiang_npc151 + '' + Jiang_npc152
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-6bd4c512dda2> in <module>
# ----> 1 Jiang_npc150 = Jiang_npc151 + '' + Jiang_npc152
#
# NameError: name 'Jiang_npc151' is not defined

# %%
print (Jiang_npc15)
# Out:
#
#
#
# e-magazine
#
#
#
#
#
#   The Hot Zone   China's newly announced air defense identification zone over the East China Sea aims to shore up national security
#
#
#
#
#
#
# Current Issue
#
#
# ·
#                         Table of Contents
#
#                     ·
#                       Editor's Desk
#
# ·
#                         Previous Issues
#
# · Subscribe to Mag
#
#
#
#
#
#
# Subscribe Now >>
#
#
#
#
#
# Expert's View
#
#
#
#
#
# World
#
#
#
#
#
# Nation
#
#
#
#
#
# Business
#
#
#
#
#
# Finance
#
#
#
#
#
# Market Watch
#
#
#
#
#
# Legal-Ease
#
#
#
#
#
# North American Report
#
#
#
#
#
# Forum
#
#
#
#
#
# Government Documents
#
#
#
#
#
# Expat's Eye
#
#
#
#
#
# Health
#
#
#
#
#
# Science/Technology
#
#
#
#
#
# Lifestyle
#
#
#
#
#
# Books
#
#
#
#
#
# Movies
#
#
#
#
#
# Backgrounders
#
#
#
#
#
# Special
#
#
#
#
#
# Photo Gallery
#
#
#
#
#
# Blogs
#
#
#
#
#
#
#
# Reader's Service
#
#
# Learning with
#               'Beijing Review'
#
#
# E-mail us
#
#
# RSS Feeds
#
#
# ...
